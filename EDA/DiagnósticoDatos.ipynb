# %%
import sqlite3
import pandas as pd

conn = sqlite3.connect(r"../Datos/data_accidentes.sqlite3")

# %%
accidentes = pd.read_sql("SELECT * FROM accidentes", conn, parse_dates=["TW"])
clima = pd.read_sql("SELECT * FROM clima", conn, parse_dates=["TW"])
raw = pd.read_sql("SELECT * FROM raw_accidentes", conn, parse_dates=["TW"])

conn.close()

# %%
print(accidentes.info())
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 120587 entries, 0 to 120586
# Data columns (total 8 columns):
#  #   Column   Non-Null Count   Dtype
# ---  ------   --------------   -----
#  0   TW       120587 non-null  datetime64[us]
#  1   BARRIO   120587 non-null  str
#  2   Lat      120587 non-null  float64
#  3   Lon      120587 non-null  float64
#  4   Dia_sem  120587 non-null  str
#  5   Mes      120587 non-null  int64
#  6   Dia      120587 non-null  int64
#  7   Hora     120587 non-null  int64
# dtypes: datetime64[us](1), float64(2), int64(3), str(2)
# memory usage: 7.4 MB
# None

# %%
print(accidentes.describe())
# Out:
#                                TW            Lat            Lon  \
# count                      120587  120587.000000  120587.000000
# mean   2018-07-06 12:34:24.849444       6.250409     -75.577050
# min           2017-01-01 00:00:00       6.166846     -75.701661
# 25%           2017-09-26 04:30:00       6.231917     -75.586833
# 50%           2018-07-05 08:00:00       6.250199     -75.574805
# 75%           2019-04-17 09:00:00       6.271710     -75.564987
# max           2019-12-31 23:00:00       6.368394     -75.480742
# std                           NaN       0.028644       0.019157
#
#                  Mes            Dia           Hora
# count  120587.000000  120587.000000  120587.000000
# mean        6.662509      15.623624      13.262997
# min         1.000000       1.000000       0.000000
# 25%         4.000000       8.000000       9.000000
# 50%         7.000000      16.000000      14.000000
# 75%        10.000000      23.000000      17.000000
# max        12.000000      31.000000      23.000000
# std         3.405328       8.743059       5.261334

# %%
print(accidentes.isnull().sum())
# Out:
# TW         0
# BARRIO     0
# Lat        0
# Lon        0
# Dia_sem    0
# Mes        0
# Dia        0
# Hora       0
# dtype: int64
# ----------------------------------------------------------------------------------------------------

# %%
print(accidentes.duplicated().sum())
# Out:
# 0

# %%
print(clima.info())
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 7991780 entries, 0 to 7991779
# Data columns (total 15 columns):
#  #   Column               Dtype
# ---  ------               -----
#  0   TW                   datetime64[us]
#  1   BARRIO               str
#  2   summary              str
#  3   icon                 str
#  4   precipIntensity      float64
#  5   precipProbability    float64
#  6   temperature          float64
#  7   apparentTemperature  float64
#  8   dewPoint             float64
#  9   humidity             float64
#  10  windSpeed            float64
#  11  windBearing          float64
#  12  cloudCover           float64
#  13  uvIndex              float64
#  14  visibility           float64
# dtypes: datetime64[us](1), float64(11), str(3)
# memory usage: 914.6 MB
# None

# %%
print(clima.describe())
# Out:
#                                TW  precipIntensity  precipProbability  \
# count                     7991780     7.444379e+06       7.444379e+06
# mean   2018-06-27 16:13:29.661927     4.761443e-01       1.595900e-01
# min           2017-01-01 00:00:00     0.000000e+00       0.000000e+00
# 25%           2017-09-26 12:00:00     0.000000e+00       0.000000e+00
# 50%           2018-06-25 06:00:00     3.020000e-02       6.000000e-02
# 75%           2019-03-27 15:00:00     6.058000e-01       2.600000e-01
# max           2019-12-31 23:00:00     2.082360e+01       1.000000e+00
# std                           NaN     8.919243e-01       2.195526e-01
#
#         temperature  apparentTemperature      dewPoint      humidity  \
# count  7.991170e+06         7.991170e+06  7.991475e+06  7.990865e+06
# mean   1.965380e+01         1.972720e+01  1.433862e+01  7.343608e-01
# min    4.510000e+00         4.510000e+00  2.160000e+00  1.700000e-01
# 25%    1.683000e+01         1.689000e+01  1.300000e+01  6.400000e-01
# 50%    1.861000e+01         1.871000e+01  1.442000e+01  7.400000e-01
# 75%    2.252000e+01         2.260000e+01  1.579000e+01  8.500000e-01
# max    3.599000e+01         3.806000e+01  2.404000e+01  1.000000e+00
# std    3.753267e+00         3.757843e+00  2.032550e+00  1.554380e-01
#
#           windSpeed   windBearing    cloudCover       uvIndex    visibility
# count  7.958987e+06  6.959267e+06  7.983830e+06  7.987500e+06  7.987490e+06
# mean   1.582619e+00  1.113286e+02  7.224333e-01  2.004863e+00  1.131779e+01
# min    0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  9.900000e-02
# 25%    8.100000e-01  6.200000e+01  5.200000e-01  0.000000e+00  1.000300e+01
# 50%    1.360000e+00  9.000000e+01  7.500000e-01  0.000000e+00  1.000300e+01
# 75%    2.090000e+00  1.350000e+02  9.000000e-01  4.000000e+00  1.502000e+01
# max    1.526000e+01  3.590000e+02  1.000000e+00  1.400000e+01  1.609300e+01
# std    1.257904e+00  8.104716e+01  2.079337e-01  2.870109e+00  3.397533e+00

# %%
print(clima.isnull().sum())
# Out:
# TW                           0
# BARRIO                       0
# summary                 548641
# icon                    548641
# precipIntensity         547401
# precipProbability       547401
# temperature                610
# apparentTemperature        610
# dewPoint                   305
# humidity                   915
# windSpeed                32793
# windBearing            1032513
# cloudCover                7950
# uvIndex                   4280
# visibility                4290
# dtype: int64

# %%
print(clima.duplicated().sum())
# Out:
# 0
